# %% [markdown]
# # Excercise: Median

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

incomes = np.random.normal( 100.0, 20.0, 10000 )
plt.hist(incomes,50)
plt.show()

# %% [markdown]
# Find the mean, median and mode of the obtained data

# %%
mean = incomes.mean()
median = np.median(incomes)
mode = stats.mode(incomes)[0]

print(f"The mean is {mean:.2f}")
print(f"The median is {median:.2f}")
print(f"The mode is {mode:.2f}")
# Out:
# The mean is 100.32
# The median is 100.40
# The mode is 30.31
